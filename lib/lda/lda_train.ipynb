# %%
import re
import glob
import gensim
from stop_words import get_stop_words
from nltk import sent_tokenize,word_tokenize
from nltk.stem.porter import PorterStemmer

# %%
def tokenize(text):
    word = re.compile('^[a-z]+$',re.IGNORECASE)
    en_stop = get_stop_words('en')
    p_stemmer = PorterStemmer()
    tokens = []
    #for sent in sent_tokenize(text):
    for tok in word_tokenize(text,preserve_line=False):
        tok = tok.lower()
        if tok not in en_stop:
            term = word.match(tok)
            if term is not None:
                tokens.append(p_stemmer.stem(tok))
    return tokens

# %%
def parse(files,encoding="utf-8"):
    texts = []
    for filename in files: # for each relevant file
        texts.append(tokenize(open(filename,encoding=encoding).read()))
    return texts

# %%
def prepare(files,encoding="utf-8"):
    texts = parse(files,encoding=encoding)
    print('parsed texts')
    dictionary = gensim.corpora.Dictionary(texts)
    print('dictionary created')
    corpus = [dictionary.doc2bow(text) for text in texts]
    print('corpus ready')
    return texts,dictionary,corpus

# %%
def train(files,num_topics=20,passes=20,encoding="utf-8"):
    texts,dictionary,corpus = prepare(files,encoding=encoding)
    ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics=num_topics, id2word = dictionary, passes=passes)
    print('model complete')
    return ldamodel

# %%
files_check = ['../../content/osc/test/free-lunch.txt']
files_train = glob.glob("../../content/osc/data/*.txt")

# %%
ldamodel = train(files_train,encoding="ISO-8859-1")
ldamodel.save('ldamodel_osc.pickle', separately=None, sep_limit=10485760, ignore=frozenset([]), pickle_protocol=2)
# Out:
# parsed texts
# dictionary created
# corpus ready
# model complete

# %%
def printtopics(ldamodel):
    alltopics = ldamodel.print_topics(num_topics=20,num_words=20)
    topics = []
    for tops in alltopics:
        for top in tops[1].split('+'):
            parts = top.split('*')
            topics.append([float(parts[0]),parts[1].replace('"','').strip()])
    topics = sorted(topics,key=lambda x:x[0],reverse=True)
    for topic in topics:
        print(str(topic[0]) + '\t' + topic[1])
printtopics(ldamodel)
# Out:
# 0.067	depend
# 0.063	solr
# 0.057	search
# 0.054	artifact
# 0.034	instal
# 0.023	field
# 0.022	confer
# 0.022	file
# 0.022	download
# 0.022	cassandra
# 0.022	document
# 0.02	scorer
# 0.019	solr
# 0.018	use
# 0.018	relev
# 0.018	patent
# 0.017	queri
# 0.017	quepid
# 0.017	queri
# 0.017	search
# 0.017	data
# 0.017	score
# 0.016	present
# 0.016	user
# 0.016	score
# 0.015	http
# 0.015	solr
# 0.015	data
# 0.014	rate
# 0.014	function
# 0.014	document
# 0.014	estim
# 0.014	open
# 0.013	can
# 0.013	result
# 0.013	podcast
# 0.013	like
# 0.013	command
# 0.013	deploy
# 0.013	central
# 0.013	use
# 0.013	life
# 0.013	search
# 0.013	agil
# 0.013	will
# 0.012	like
# 0.012	can
# 0.012	mvn
# 0.012	queri
# 0.012	use
# 0.012	second
# 0.012	term
# 0.012	use
# 0.012	search
# 0.012	sourc
# 0.011	will
# 0.011	groovi
# 0.011	http
# 0.011	use
# 0.011	project
# 0.011	rank
# 0.011	solr
# 0.011	document
# 0.011	use
# 0.011	can
# 0.011	test
# 0.011	work
# 0.01	code
# 0.01	like
# 0.01	use
# 0.01	java
# 0.01	directori
# 0.01	award
# 0.01	time
# 0.01	project
# 0.01	posit
# 0.01	ndcg
# 0.01	use
# 0.01	work
# 0.01	index
# 0.01	document
# 0.01	queri
# 0.01	queri
# 0.01	develop
# 0.01	can
# 0.01	can
# 0.009	data
# 0.009	great
# 0.009	can
# 0.009	use
# 0.009	url
# 0.009	custom
# 0.009	will
# 0.009	list
# 0.009	grade
# 0.009	rubi
# 0.009	can
# 0.009	field
# 0.009	match
# 0.009	synonym
# 0.009	codec
# 0.009	will
# 0.009	result
# 0.009	match
# 0.009	solr
# 0.009	develop
# 0.009	project
# 0.009	can
# 0.009	use
# 0.009	use
# 0.009	need
# 0.009	run
# 0.008	session
# 0.008	peopl
# 0.008	talk
# 0.008	work
# 0.008	use
# 0.008	instal
# 0.008	test
# 0.008	innov
# 0.008	friend
# 0.008	repositori
# 0.008	tri
# 0.008	can
# 0.008	path
# 0.008	work
# 0.008	can
# 0.008	case
# 0.008	result
# 0.008	learn
# 0.008	set
# 0.008	class
# 0.008	php
# 0.008	rail
# 0.008	token
# 0.008	valu
# 0.008	bodi
# 0.008	use
# 0.008	x
# 0.008	frequenc
# 0.008	scrum
# 0.008	project
# 0.008	can
# 0.008	use
# 0.008	airport
# 0.007	group
# 0.007	discuss
# 0.007	attend
# 0.007	inform
# 0.007	get
# 0.007	data
# 0.007	just
# 0.007	elasticsearch
# 0.007	get
# 0.007	solr
# 0.007	engin
# 0.007	sourc
# 0.007	debug
# 0.007	exampl
# 0.007	cbic
# 0.007	cqlsh
# 0.007	use
# 0.007	doug
# 0.007	list
# 0.007	user
# 0.007	basket
# 0.007	websit
# 0.007	fetch
# 0.007	use
# 0.007	go
# 0.007	log
# 0.007	predict
# 0.007	judgment
# 0.007	will
# 0.007	can
# 0.007	languag
# 0.007	one
# 0.007	term
# 0.007	text
# 0.007	follow
# 0.007	b
# 0.007	data
# 0.007	c
# 0.007	like
# 0.007	solr
# 0.007	user
# 0.007	get
# 0.007	one
# 0.007	cassandra
# 0.007	can
# 0.007	run
# 0.007	search
# 0.007	time
# 0.007	snapshot
# 0.007	one
# 0.007	govern
# 0.007	will
# 0.007	softwar
# 0.007	data
# 0.007	contain
# 0.006	integr
# 0.006	can
# 0.006	learn
# 0.006	applic
# 0.006	web
# 0.006	use
# 0.006	eric
# 0.006	file
# 0.006	new
# 0.006	make
# 0.006	learn
# 0.006	rank
# 0.006	work
# 0.006	lucid
# 0.006	camel
# 0.006	lucen
# 0.006	can
# 0.006	project
# 0.006	busi
# 0.006	googl
# 0.006	nomin
# 0.006	charlottesvil
# 0.006	set
# 0.006	matt
# 0.006	count
# 0.006	b
# 0.006	one
# 0.006	databas
# 0.006	item
# 0.006	need
# 0.006	new
# 0.006	scorer
# 0.006	custom
# 0.006	return
# 0.006	will
# 0.006	like
# 0.006	analyz
# 0.006	data
# 0.006	int
# 0.006	user
# 0.006	will
# 0.006	exampl
# 0.006	time
# 0.006	return
# 0.006	look
# 0.006	databas
# 0.006	friend
# 0.006	can
# 0.006	inform
# 0.006	one
# 0.006	text
# 0.006	will
# 0.006	name
# 0.006	test
# 0.006	client
# 0.006	cluster
# 0.006	team
# 0.006	busi
# 0.006	predict
# 0.006	web
# 0.006	can
# 0.006	need
# 0.006	make
# 0.006	one
# 0.006	time
# 0.006	node
# 0.006	id
# 0.006	new
# 0.006	token
# 0.006	index
# 0.006	get
# 0.006	search
# 0.006	get
# 0.005	event
# 0.005	creat
# 0.005	one
# 0.005	develop
# 0.005	run
# 0.005	go
# 0.005	want
# 0.005	thing
# 0.005	time
# 0.005	problem
# 0.005	featur
# 0.005	one
# 0.005	need
# 0.005	score
# 0.005	server
# 0.005	connect
# 0.005	jetti
# 0.005	see
# 0.005	now
# 0.005	user
# 0.005	decemb
# 0.005	new
# 0.005	control
# 0.005	recommend
# 0.005	test
# 0.005	just
# 0.005	relat
# 0.005	number
# 0.005	system
# 0.005	rank
# 0.005	get
# 0.005	busi
# 0.005	develop
# 0.005	want
# 0.005	can
# 0.005	weight
# 0.005	score
# 0.005	like
# 0.005	get
# 0.005	document
# 0.005	get
# 0.005	titl
# 0.005	will
# 0.005	reduc
# 0.005	new
# 0.005	cours
# 0.005	cluster
# 0.005	standard
# 0.005	user
# 0.005	edison
# 0.005	busi
# 0.005	can
# 0.005	connect
# 0.005	world
# 0.005	titl
# 0.005	exampl
# 0.005	chang
# 0.005	also
# 0.005	time
# 0.005	valu
# 0.005	set
# 0.005	go
# 0.005	use
# 0.005	exist
# 0.005	autom
# 0.005	get
# 0.005	like
# 0.005	team
# 0.005	data
# 0.005	get
# 0.005	day
# 0.005	technolog
# 0.005	take
# 0.005	http
# 0.005	inform
# 0.005	use
# 0.005	work
# 0.005	provid
# 0.005	team
# 0.005	get
# 0.005	compani
# 0.005	word
# 0.005	time
# 0.005	set
# 0.005	one
# 0.005	cach
# 0.005	filter
# 0.005	work
# 0.005	queri
# 0.005	work
# 0.005	time
# 0.005	applic
# 0.005	log
# 0.004	also
# 0.004	go
# 0.004	someth
# 0.004	realli
# 0.004	might
# 0.004	facebook
# 0.004	process
# 0.004	technolog
# 0.004	look
# 0.004	like
# 0.004	compani
# 0.004	one
# 0.004	manag
# 0.004	like
# 0.004	datastax
# 0.004	prior
# 0.004	need
# 0.004	inform
# 0.004	art
# 0.004	will
# 0.004	make
# 0.004	thing
# 0.004	make
# 0.004	point
# 0.004	idea
# 0.004	topic
# 0.004	updat
# 0.004	start
# 0.004	now
# 0.004	just
# 0.004	set
# 0.004	like
# 0.003	septemb
# 0.003	govern

# %%
test_texts,test_dictionary,test_corpus = prepare(files_check)
test_topics = ldamodel[test_corpus]
# Out:
# parsed texts
# dictionary created
# corpus ready

# %%
for test_topic in test_topics:
    for t in test_topic:
        print(ldamodel.show_topic(t[0]))
# Out:
# [('confer', 0.022444598), ('present', 0.015677268), ('will', 0.011301638), ('data', 0.0091455989), ('great', 0.0089752432), ('session', 0.0081362063), ('peopl', 0.0081142662), ('talk', 0.0078431945), ('group', 0.007466238), ('discuss', 0.0069808643)]
# [('like', 0.013304528), ('can', 0.01225144), ('use', 0.0088527529), ('user', 0.0070516146), ('basket', 0.0065877079), ('count', 0.0061847982), ('b', 0.005976839), ('one', 0.0058578565), ('databas', 0.0056053838), ('item', 0.0055015502)]
# [('project', 0.010803971), ('custom', 0.009281191), ('will', 0.0087867724), ('work', 0.0084994696), ('can', 0.0078534093), ('use', 0.0068423925), ('go', 0.0066181845), ('need', 0.005911049), ('get', 0.0054968582), ('busi', 0.0054925266)]
# [('queri', 0.01744362), ('search', 0.017039541), ('use', 0.012013937), ('solr', 0.011153456), ('document', 0.010794309), ('index', 0.010339779), ('can', 0.0094706248), ('field', 0.0094019668), ('match', 0.0091341082), ('synonym', 0.008787889)]
# [('agil', 0.013197406), ('will', 0.012592415), ('use', 0.012159834), ('develop', 0.0093535865), ('project', 0.0091610504), ('scrum', 0.0082984921), ('one', 0.0074011269), ('cassandra', 0.0073779789), ('can', 0.0069143432), ('run', 0.0067933593)]
# [('open', 0.013758861), ('search', 0.011777053), ('sourc', 0.011648078), ('develop', 0.0099400608), ('can', 0.0097905006), ('project', 0.0075081517), ('govern', 0.0073716454), ('will', 0.0067837159), ('softwar', 0.0066594887), ('need', 0.0062830695)]

# %%
print(test_topics)
# Out:
# <gensim.interfaces.TransformedCorpus object at 0x11617cf28>
